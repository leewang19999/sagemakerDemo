# %%
# !pip install sagemaker
import sagemaker

sagemaker_session = sagemaker.Session()

bucket = sagemaker_session.default_bucket()
prefix = "pytorch-cnn-cifar10-example"

role = sagemaker.get_execution_role()

# %%
# !pip install torch
import torch
import torchvision
import torchvision.transforms as transforms

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 4

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(batch_size)))
# Out:
# [2022-01-04 03:48:56.251 pytorch-1-6-gpu-py36--ml-t3-medium-36f26fde907cda520ad26c37441f:997 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-01-04 03:48:56.420 pytorch-1-6-gpu-py36--ml-t3-medium-36f26fde907cda520ad26c37441f:997 INFO profiler_config_parser.py:102] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.
#  frog plane   cat truck

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net()

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
for epoch in range(2):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0

print('Finished Training')
# Out:
# [1,  2000] loss: 2.171
# [1,  4000] loss: 1.801
# [1,  6000] loss: 1.656
# [1,  8000] loss: 1.560
# [1, 10000] loss: 1.513
# [1, 12000] loss: 1.458
# [2,  2000] loss: 1.399
# [2,  4000] loss: 1.369
# [2,  6000] loss: 1.345
# [2,  8000] loss: 1.312
# [2, 10000] loss: 1.310
# [2, 12000] loss: 1.297
# Finished Training

# %%
PATH = './cifar_net.pth'
torch.save(net.state_dict(), PATH)

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane

# %%
# load model
net = Net()
net.load_state_dict(torch.load(PATH))
outputs = net(images)

# %%
outputs
# Out:
# tensor([[-0.8974, -2.5701,  1.5347,  2.3212, -0.7669,  1.7699,  0.8307, -0.7927,
#          -1.0602, -2.0966],
#         [ 4.0895,  4.1452, -2.3935, -3.6257, -2.6589, -4.6566, -4.5672, -3.1854,
#           5.8656,  4.2946],
#         [ 2.1605,  3.2209, -1.7060, -1.9269, -1.7384, -2.9923, -2.4177, -2.6797,
#           2.9069,  3.1102],
#         [ 1.8740,  0.4863,  0.2081, -1.1357, -0.7937, -1.9959, -1.7996, -1.5396,
#           2.5212,  1.1341]], grad_fn=<AddmmBackward>)

# %%
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Predicted:    cat  ship   car  ship

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
        images, labels = data
        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 10000 test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 53 %

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print("Accuracy for class {:5s} is: {:.1f} %".format(classname,
                                                   accuracy))
# Out:
# Accuracy for class plane is: 61.1 %
# Accuracy for class car   is: 33.3 %
# Accuracy for class bird  is: 35.3 %
# Accuracy for class cat   is: 29.1 %
# Accuracy for class deer  is: 50.8 %
# Accuracy for class dog   is: 48.7 %
# Accuracy for class frog  is: 63.9 %
# Accuracy for class horse is: 74.5 %
# Accuracy for class ship  is: 64.3 %
# Accuracy for class truck is: 78.0 %

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cpu

# %%
# !ls
# !unzip yolov4-byom.zip
# Out:
# CityHackDemo.ipynb		      data
# Untitled.ipynb			      pytorch
# amazon-sagemaker-examples-master      requirements.txt
# amazon-sagemaker-examples-master.zip  source
# cifar-10-batches-py		      stock-prediction-pytorch.ipynb
# cifar_net.pth			      yolov4-byom.zip
# Archive:  yolov4-byom.zip
#    creating: yolov4-byom/
#   inflating: __MACOSX/._yolov4-byom
#   inflating: yolov4-byom/dataset.names
#   inflating: __MACOSX/yolov4-byom/._dataset.names
#   inflating: yolov4-byom/.DS_Store
#   inflating: __MACOSX/yolov4-byom/._.DS_Store
#   inflating: yolov4-byom/models.py
#   inflating: __MACOSX/yolov4-byom/._models.py
#    creating: yolov4-byom/test/
#   inflating: __MACOSX/yolov4-byom/._test
#   inflating: yolov4-byom/e2e_yolov4_training.ipynb
#   inflating: __MACOSX/yolov4-byom/._e2e_yolov4_training.ipynb
#   inflating: yolov4-byom/README.md
#   inflating: __MACOSX/yolov4-byom/._README.md
#   inflating: yolov4-byom/predictions.jpg
#   inflating: __MACOSX/yolov4-byom/._predictions.jpg
#   inflating: yolov4-byom/utils.py
#   inflating: __MACOSX/yolov4-byom/._utils.py
#   inflating: yolov4-byom/model.pth
#   inflating: __MACOSX/yolov4-byom/._model.pth
#    creating: yolov4-byom/train/
#   inflating: __MACOSX/yolov4-byom/._train
#    creating: yolov4-byom/inference/
#   inflating: __MACOSX/yolov4-byom/._inference
#    creating: yolov4-byom/.ipynb_checkpoints/
#   inflating: __MACOSX/yolov4-byom/._.ipynb_checkpoints
#    creating: yolov4-byom/.git/
#   inflating: __MACOSX/yolov4-byom/._.git
#   inflating: yolov4-byom/test/092708649_jpg.rf.47dd9a6e6b4346a49a874db46abea480.jpg
#   inflating: __MACOSX/yolov4-byom/test/._092708649_jpg.rf.47dd9a6e6b4346a49a874db46abea480.jpg
#   inflating: yolov4-byom/test/019477314_jpg.rf.4c7a19e36c13ecd7416f25577b55f568.jpg
#   inflating: __MACOSX/yolov4-byom/test/._019477314_jpg.rf.4c7a19e36c13ecd7416f25577b55f568.jpg
#    creating: yolov4-byom/test/.ipynb_checkpoints/
#   inflating: __MACOSX/yolov4-byom/test/._.ipynb_checkpoints
#   inflating: yolov4-byom/train/Dockerfile
#   inflating: __MACOSX/yolov4-byom/train/._Dockerfile
#   inflating: yolov4-byom/train/dataset.py
#   inflating: __MACOSX/yolov4-byom/train/._dataset.py
#   inflating: yolov4-byom/train/train.py
#   inflating: __MACOSX/yolov4-byom/train/._train.py
#    creating: yolov4-byom/train/.ipynb_checkpoints/
#   inflating: __MACOSX/yolov4-byom/train/._.ipynb_checkpoints
#   inflating: yolov4-byom/train/build_and_push_container.sh
#   inflating: __MACOSX/yolov4-byom/train/._build_and_push_container.sh
#   inflating: yolov4-byom/inference/requirements.txt
#   inflating: __MACOSX/yolov4-byom/inference/._requirements.txt
#   inflating: yolov4-byom/inference/inference.py
#   inflating: __MACOSX/yolov4-byom/inference/._inference.py
#    creating: yolov4-byom/inference/.ipynb_checkpoints/
#   inflating: __MACOSX/yolov4-byom/inference/._.ipynb_checkpoints
#   inflating: yolov4-byom/.ipynb_checkpoints/predictions-checkpoint.jpg
#   inflating: __MACOSX/yolov4-byom/.ipynb_checkpoints/._predictions-checkpoint.jpg
#   inflating: yolov4-byom/.ipynb_checkpoints/README-checkpoint.md
#   inflating: __MACOSX/yolov4-byom/.ipynb_checkpoints/._README-checkpoint.md
#   inflating: yolov4-byom/.ipynb_checkpoints/e2e_yolov4_training-checkpoint.ipynb
#   inflating: __MACOSX/yolov4-byom/.ipynb_checkpoints/._e2e_yolov4_training-checkpoint.ipynb
#   inflating: yolov4-byom/.ipynb_checkpoints/dataset-checkpoint.names
#   inflating: __MACOSX/yolov4-byom/.ipynb_checkpoints/._dataset-checkpoint.names
#   inflating: yolov4-byom/.git/config
#   inflating: __MACOSX/yolov4-byom/.git/._config
#    creating: yolov4-byom/.git/objects/
#   inflating: __MACOSX/yolov4-byom/.git/._objects
#   inflating: yolov4-byom/.git/HEAD
#   inflating: __MACOSX/yolov4-byom/.git/._HEAD
#    creating: yolov4-byom/.git/info/
#   inflating: __MACOSX/yolov4-byom/.git/._info
#    creating: yolov4-byom/.git/logs/
#   inflating: __MACOSX/yolov4-byom/.git/._logs
#   inflating: yolov4-byom/.git/description
#   inflating: __MACOSX/yolov4-byom/.git/._description
#    creating: yolov4-byom/.git/hooks/
#   inflating: __MACOSX/yolov4-byom/.git/._hooks
#    creating: yolov4-byom/.git/refs/
#   inflating: __MACOSX/yolov4-byom/.git/._refs
#   inflating: yolov4-byom/.git/index
#   inflating: __MACOSX/yolov4-byom/.git/._index
#    creating: yolov4-byom/.git/branches/
#   inflating: __MACOSX/yolov4-byom/.git/._branches
#   inflating: yolov4-byom/.git/packed-refs
#   inflating: __MACOSX/yolov4-byom/.git/._packed-refs
#   inflating: yolov4-byom/test/.ipynb_checkpoints/019477314_jpg.rf.4c7a19e36c13ecd7416f25577b55f568-checkpoint.jpg
#   inflating: __MACOSX/yolov4-byom/test/.ipynb_checkpoints/._019477314_jpg.rf.4c7a19e36c13ecd7416f25577b55f568-checkpoint.jpg
#   inflating: yolov4-byom/train/.ipynb_checkpoints/dataset-checkpoint.py
#   inflating: __MACOSX/yolov4-byom/train/.ipynb_checkpoints/._dataset-checkpoint.py
#   inflating: yolov4-byom/train/.ipynb_checkpoints/build_and_push_container-checkpoint.sh
#   inflating: __MACOSX/yolov4-byom/train/.ipynb_checkpoints/._build_and_push_container-checkpoint.sh
#   inflating: yolov4-byom/train/.ipynb_checkpoints/train-checkpoint.py
#   inflating: __MACOSX/yolov4-byom/train/.ipynb_checkpoints/._train-checkpoint.py
#   inflating: yolov4-byom/inference/.ipynb_checkpoints/inference-checkpoint.py
#   inflating: __MACOSX/yolov4-byom/inference/.ipynb_checkpoints/._inference-checkpoint.py
#    creating: yolov4-byom/.git/objects/3e/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._3e
#    creating: yolov4-byom/.git/objects/50/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._50
#    creating: yolov4-byom/.git/objects/57/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._57
#    creating: yolov4-byom/.git/objects/69/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._69
#    creating: yolov4-byom/.git/objects/51/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._51
#    creating: yolov4-byom/.git/objects/ad/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._ad
#    creating: yolov4-byom/.git/objects/d0/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._d0
#    creating: yolov4-byom/.git/objects/df/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._df
#    creating: yolov4-byom/.git/objects/a5/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._a5
#    creating: yolov4-byom/.git/objects/bd/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._bd
#    creating: yolov4-byom/.git/objects/d8/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._d8
#    creating: yolov4-byom/.git/objects/ab/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._ab
#    creating: yolov4-byom/.git/objects/f4/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._f4
#    creating: yolov4-byom/.git/objects/f2/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._f2
#    creating: yolov4-byom/.git/objects/e3/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._e3
#    creating: yolov4-byom/.git/objects/ec/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._ec
#    creating: yolov4-byom/.git/objects/pack/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._pack
#    creating: yolov4-byom/.git/objects/89/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._89
#    creating: yolov4-byom/.git/objects/72/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._72
#    creating: yolov4-byom/.git/objects/38/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._38
#    creating: yolov4-byom/.git/objects/5c/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._5c
#    creating: yolov4-byom/.git/objects/info/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._info
#    creating: yolov4-byom/.git/objects/5b/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._5b
#    creating: yolov4-byom/.git/objects/6c/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._6c
#    creating: yolov4-byom/.git/objects/52/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._52
#    creating: yolov4-byom/.git/objects/0a/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._0a
#    creating: yolov4-byom/.git/objects/bf/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._bf
#    creating: yolov4-byom/.git/objects/a0/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._a0
#    creating: yolov4-byom/.git/objects/b8/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._b8
#    creating: yolov4-byom/.git/objects/dc/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._dc
#    creating: yolov4-byom/.git/objects/b6/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._b6
#    creating: yolov4-byom/.git/objects/d5/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._d5
#    creating: yolov4-byom/.git/objects/d2/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._d2
#    creating: yolov4-byom/.git/objects/de/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._de
#    creating: yolov4-byom/.git/objects/a1/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._a1
#    creating: yolov4-byom/.git/objects/c4/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._c4
#    creating: yolov4-byom/.git/objects/e6/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._e6
#    creating: yolov4-byom/.git/objects/e9/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._e9
#    creating: yolov4-byom/.git/objects/e7/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._e7
#    creating: yolov4-byom/.git/objects/2c/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._2c
#    creating: yolov4-byom/.git/objects/12/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._12
#    creating: yolov4-byom/.git/objects/8c/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._8c
#    creating: yolov4-byom/.git/objects/8e/
#   inflating: __MACOSX/yolov4-byom/.git/objects/._8e
#   inflating: yolov4-byom/.git/info/exclude
#   inflating: __MACOSX/yolov4-byom/.git/info/._exclude
#   inflating: yolov4-byom/.git/logs/HEAD
#   inflating: __MACOSX/yolov4-byom/.git/logs/._HEAD
#    creating: yolov4-byom/.git/logs/refs/
#   inflating: __MACOSX/yolov4-byom/.git/logs/._refs
#   inflating: yolov4-byom/.git/hooks/commit-msg.sample
#   inflating: __MACOSX/yolov4-byom/.git/hooks/._commit-msg.sample
#   inflating: yolov4-byom/.git/hooks/pre-rebase.sample
#   inflating: __MACOSX/yolov4-byom/.git/hooks/._pre-rebase.sample
#   inflating: yolov4-byom/.git/hooks/pre-commit.sample
#   inflating: __MACOSX/yolov4-byom/.git/hooks/._pre-commit.sample
#   inflating: yolov4-byom/.git/hooks/applypatch-msg.sample
#   inflating: __MACOSX/yolov4-byom/.git/hooks/._applypatch-msg.sample
#   inflating: yolov4-byom/.git/hooks/fsmonitor-watchman.sample
#   inflating: __MACOSX/yolov4-byom/.git/hooks/._fsmonitor-watchman.sample
#   inflating: yolov4-byom/.git/hooks/pre-receive.sample
#   inflating: __MACOSX/yolov4-byom/.git/hooks/._pre-receive.sample
#   inflating: yolov4-byom/.git/hooks/prepare-commit-msg.sample
#   inflating: __MACOSX/yolov4-byom/.git/hooks/._prepare-commit-msg.sample
#   inflating: yolov4-byom/.git/hooks/post-update.sample
#   inflating: __MACOSX/yolov4-byom/.git/hooks/._post-update.sample
#   inflating: yolov4-byom/.git/hooks/pre-applypatch.sample
#   inflating: __MACOSX/yolov4-byom/.git/hooks/._pre-applypatch.sample
#   inflating: yolov4-byom/.git/hooks/pre-push.sample
#   inflating: __MACOSX/yolov4-byom/.git/hooks/._pre-push.sample
#   inflating: yolov4-byom/.git/hooks/update.sample
#   inflating: __MACOSX/yolov4-byom/.git/hooks/._update.sample
#    creating: yolov4-byom/.git/refs/heads/
#   inflating: __MACOSX/yolov4-byom/.git/refs/._heads
#    creating: yolov4-byom/.git/refs/tags/
#   inflating: __MACOSX/yolov4-byom/.git/refs/._tags
#    creating: yolov4-byom/.git/refs/remotes/
#   inflating: __MACOSX/yolov4-byom/.git/refs/._remotes
#   inflating: yolov4-byom/.git/objects/3e/0222081795d987ed98462f0d1af8fca09cf431
#   inflating: __MACOSX/yolov4-byom/.git/objects/3e/._0222081795d987ed98462f0d1af8fca09cf431
#   inflating: yolov4-byom/.git/objects/50/08ddfcf53c02e82d7eee2e57c38e5672ef89f6
#   inflating: __MACOSX/yolov4-byom/.git/objects/50/._08ddfcf53c02e82d7eee2e57c38e5672ef89f6
#   inflating: yolov4-byom/.git/objects/57/5859d59949163058c3d26805cc399934c1d6e0
#   inflating: __MACOSX/yolov4-byom/.git/objects/57/._5859d59949163058c3d26805cc399934c1d6e0
#   inflating: yolov4-byom/.git/objects/69/e866275f09f533ca1f8c1a041ad2a4628de52c
#   inflating: __MACOSX/yolov4-byom/.git/objects/69/._e866275f09f533ca1f8c1a041ad2a4628de52c
#   inflating: yolov4-byom/.git/objects/69/35b0674fdcaa84e38af676d31ec3c4dadf40bb
